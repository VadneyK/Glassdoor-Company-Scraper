# %% [markdown]
# # Professor Fedyk URAP Interview Task: Glassdoor Scraper

# %% [markdown]
# ## Step 1: Build GlassDoor Seed URL list.

# %%
import time

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

import pandas as pd
import numpy as np
import nltk

import jsonlines
import json
import csv

wait=.05

# %%
# Get all data we need to search the company from files

name = []
longName = []
ticker = []

with open('gvkey_salary_company_seeds.jsonl') as reader:
    for line in reader:
        company = json.loads(line)
        
        name.append(company['name'])
        longName.append(company['longname'])
        ticker.append(company['capiq-ticker'])

# %%
# Process out the legal words from the 'long name' to get common names

common = pd.Series(longName)

with open('legal.csv', newline='') as legal:
    reader = csv.reader(legal)
    legalTerms = list(reader)[0][1:]
    
    
    #Special case for words with '(The)'
    common = common.apply(lambda x: 'The ' + x.replace('(The)', '') if '(The)' in x else x)
    
    for term in legalTerms:
        common = common.apply(lambda x: x.replace(term, '') if (type(x)==str and x.endswith(term)) else x)

        
print(common)
# Out:
# 0                                AAR
# 1                  American Airlines
# 2                 CECO Environmental
# 3       ASA Gold and Precious Metals
# 4                                AVX
#                     ...
# 5805                  nVent Electric
# 5806               Grindrod Shipping
# 5807      Navios Maritime Containers
# 5808                          Arcosa
# 5809                 Castor Maritime
# Length: 5810, dtype: object

# %%
#Now we begin the search for seeds. below are helper functions to help divide up the task.

def sign_in(args):
    url = 'https://www.glassdoor.com/profile/login_input.htm'
    browser.get(url)
    time.sleep(wait)
    
    email_field = browser.find_element_by_name('username')
    password_field = browser.find_element_by_name('password')
    submit_btn = browser.find_element_by_xpath('//button[@type="submit"]')

    email_field.send_keys(args['username'])
    password_field.send_keys(args['password'])
    submit_btn.click()

    time.sleep(wait)
    browser.get(args['url'])

# %%
def search_word(c):
    '''Accesses the search bar and inputs all information
    and submits the search.
    '''
    keyword = browser.find_element(By.XPATH, '//*[@id="sc.keyword"]')
    keyword.clear()
    keyword.send_keys(c)
    time.sleep(wait)

    dropdown = browser.find_element(By.XPATH, '//*[@id="scBar"]/div/div[2]/div')
    dropdown.click()
    time.sleep(wait)

    selectCompany = browser.find_element(By.XPATH, '//*[@id="option_1"]')
    selectCompany.click()
    time.sleep(wait)

    #.clear() doesnt work so harcoded backspace
    location = browser.find_element(By.XPATH,'//*[@id="sc.location"]')
    for i in range(50):
        location.send_keys(Keys.BACK_SPACE)

    searchBtn = browser.find_element(By.XPATH,'//*[@id="scBar"]/div/button/span')
    searchBtn.click()
    time.sleep(wait)
    
    #Some times random pop ups come to block the scraper if the scraper goes too fast.
    #optionally uncomment below if this happens.
    # try:
    #     browser.find_element_by_class_name("selected").click()
    # except ElementClickInterceptedException:
    #     pass

    # time.sleep(wait)

    # try:
    #     browser.find_element_by_class_name("ModalStyle__xBtn___29PT9").click()  #clicking to the X.
    # except NoSuchElementException:
    #     pass

# %%
def find_match(i, c):
    ''' finds company with name 'c' and returns link to most likely website of company 'c'
        
        Detail:
        searches through each result and checks how many times each result word matches
        with the ticker, longname, and company name. We choose the best candidates
        that match the most of these three, and determine the most likely legetimate
        site via heuristic getStat(<possible result>) and clicks on link. 
    '''
    results = browser.find_elements(By.CLASS_NAME,'single-company-result.module')

    similarNames = []
    similarStat = []
    matches = []
    
    # count matches
    for oneResult in results:
        resultName = oneResult.find_element(By.CLASS_NAME, 'col-9.pr-0')
        textLink = resultName.find_element(By.TAG_NAME, 'a')
        matchNum = checkAnyInLowerStrip(i, textLink.text)
        matches.append(matchNum)  
        
    matches = np.array(matches)
    if matches.size == 0:
        return ''
    maxMatch = max(matches)
    if maxMatch == 0:
        return ''
    else:
        # choose best stat out of best matches
        bestCandidates = np.where(matches == maxMatch)[0]
        for i in bestCandidates:
            candidate = results[i]
            oneOfBestName = candidate.find_element(By.CLASS_NAME, 'col-9.pr-0')
            textLink = oneOfBestName.find_element(By.TAG_NAME, 'a')
            similarNames.append(textLink)
            similarStat.append(getStat(candidate))
        similarNames[np.argmax(similarStat)].click()
        
        direct_name = browser.find_element(By.XPATH, '//*[@id="DivisionsDropdownComponent"]').text
        if check_public(direct_name):
            time.sleep(wait)
            return browser.current_url
        else:
            return ''

# %%
def getStat(oneResult):
    '''gets a the mean of reviews, salaries, and interviews to determine how legitimite the company profile is.
    
    the mean is used since if there is only one metric that is strong (possibly due to spamming) then this is 
    discounted by taking the mean of all three values.
    '''
    
    stats = oneResult.find_elements(By.CLASS_NAME, 'num.h2')
    nums = []
    k = 1
    for s in stats:
        s = s.text.strip().replace('--', '0')
        if 'k' in s:
            s = s.replace('k', '')
            k = 1000 # we need to multiply by 1k = 1000
        numStat = float(s) * k
        nums.append(numStat)
        
    return np.mean(nums)

# %%
def check_redirect(i, c):
    '''Occasioanlly the exact name of the comapany is entered, and we are taken to their page.
    In this case the company name may be different so we just check if either the display name
    is in what we're searching and vice versa.
    
    returns TRUE if there was a redirect
    '''
    try:
        direct_name = browser.find_element(By.XPATH, '//*[@id="DivisionsDropdownComponent"]').text
    except:
        return 'not redirect'
    print('redirected to: ', direct_name, ' when searching: ', c)
    if direct_name and direct_name != ' ':
        if checkAnyInLowerStrip(i, direct_name):
            if check_public(direct_name):
                return browser.current_url
    return 'fail'

# %% [markdown]
# Logic for private words:
# - Non-profits may issue stock publicly in some states
# - Some franchises are publicly traded
# - Hospitals can be publicly traded
# - Contracting firms may be publicly traded
# - Subsidaries may be publicly traded
# - Other is ambiguous
#
#     Thus everything else in the list must be private
#
# https://www.glassdoor.com/mz-survey/start_input.htm?cr=&c=&showSurvey=Reviews

# %%
def check_public(direct_name):
    '''all entries in JSONL files should be publicly traded.
    If any company is not publicly traded, return false
    else return true
    
    might need to adjust private words later.
    '''
    return True #many public companies are listed as private so turn off
    
    
    typeText = browser.find_element(By.XPATH, "//*[@data-test='employer-type']").text
    privateWords = ['Private', 'Government', 'College', 'School', 'Self']
    if any([p for p in privateWords if p in typeText]):
        print('Private Company found and ignored: ', direct_name)
        return ''
    else:
        return True

# %%
def get_seed_link(i, c):
    '''gets the seed link of the 'i'th word, 'c'.
    if the link is found, appends it to seeds.
    otherwise appends ''.
    '''
    link_found = find_match(i, c)
    if not link_found:
        return ''
    else:
        return link_found

# %%
def search(i, c):
    '''searches the word in the search bar via search_word(c)
    then checks if there was a redirect via check_redirect
    finally gets seed link via get_seed_link
    '''
    try:
        search_word(c)
        result = check_redirect(i, c)
        if (result == 'not redirect'):
            return get_seed_link(i, c)
        elif (result == 'fail'):
            return ''
        else:
            return result
        
    except Exception as e:
        return ''

# %%
def gather_seeds(limit):
    '''iterates from entries at index start to end to search for the seed link
    adds '' to gd-url in taskOne if not found.
    adds the link to gd-url in taskOne if found
    
    if the link is found, we go ahead and collect the 
    '''
    
    
    reader = jsonlines.open('gvkey_salary_company_seeds.jsonl', mode='r')
    
    seed = ''
    taskOne = []
    taskTwo = []
    
    for index, company in enumerate(reader):
        #if index < limit:
        #    continue
        seed = search(index, longName[index])
        if not seed:
            seed = search(index, common[index])
            #give up only after common name and long name does not work.
        company['gd-url'] = seed
        taskOne.append(company)
        
        if (seed != ''):
            collectTaskTwo(taskTwo, company.copy())
            
        limit -= 1
        
    reader.close() 
    
    return taskOne, taskTwo

# %%
def checkAnyInLowerStrip(i, word):
    ''' checks if a the common name, long name, or ticker is in word, or vise versa when stripped 
    of spaces and punctuations and lower cased are contained in eachother.
    
    Note:
    After the first successfull pass, there were many instances where one search led to another
    version of the name popping up, but it was not caught as valid. This happened as redirects and
    normal searches.
    
    Additionally the cases of the words were messing with the accuracy so everything is in lower case.
    However, the search itself is in the original case because that tends to bring the most relavent to 
    the top. The punctuations are also removed.
    
    finally we get rid of spaces since some comapnies concatinate their company names on glass door.
    '''
    
    #strip all punctuation
    tokenizer = nltk.RegexpTokenizer(r"\w+")
    word = ''.join(tokenizer.tokenize(word)).lower()

    def normalizeAndCompare(c):
        c = ''.join(tokenizer.tokenize(c)).lower()
        return c in word or word in c
    
    check = [ticker[i], common[i], longName[i]]
    result = []
    
    for item in check:
        result.append(normalizeAndCompare(item))
        
    return sum(result)

# %%
### Now we input the URLs into the jsonl file
def writeToJson(writeList, dest):
    ''' Write writeList into dest.json as json object
    '''
    jsonObject = json.dumps(writeList, indent = 4)
    with open(dest + ".json", "w") as outfile: 
        outfile.write(jsonObject)

# %%
def collectTaskTwo(taskTwo, company):
    ''' Given output list taskTwo and a dict company
    to input information, collect Overview and Top bar 
    data into the comapny dict, then append to
    taskTwo list
    '''
    collectOverview(company)
    collectTopBar(company)
    taskTwo.append(company)

# %%
def collectOverview(company):
    ''' Collect all information from the Overview pane on glassdoor.com
    '''
    infoSquare = browser.find_element(By.CLASS_NAME, 'css-155za0w.row.px-0.m-0')
    rows = infoSquare.find_elements(By.TAG_NAME, 'li')
    overview = {}
    
    # link formatted differently
    overview['website'] = rows[0].find_element(By.TAG_NAME, 'a').text 
    
    for info in rows[1:]:
        label = info.find_element(By.TAG_NAME, 'label').text 
        data = info.find_element(By.TAG_NAME, 'div').text 
        overview[label] = data
        
    company['Overview Data'] = overview

# %%
def collectTopBar(company):
    ''' Collect all information on the top bar pane of glassdoor.com
    then , enter information into company dict
    '''
    name =''
    topBarData = {}
    
    infoBar = browser.find_element(By.ID, 'EIProductHeaders')
    links = infoBar.find_elements(By.TAG_NAME, 'a')
    
    # skip first link = overview page
    overview = links[0].get_attribute("href")
    for data in links[1:]:
        link = data.get_attribute("href")
        
        if 'Reviews' in link:
            review = link
        
        if 'FAQ' in link:
            name = 'FAQ'
        elif 'Location' in link:
            name = 'Location'
        elif 'Affiliated' in link:
            name = 'Affiliated'
        else:
            textData = data.find_elements(By.TAG_NAME, 'span')
            value = textData[0].text
            name = textData[1].text
            topBarData['Number of ' +name+ ' Posted'] = value
            
        topBarData[name + ' Link'] = link
        
    reviewCase(company, review)

    company['Top bar Data'] = topBarData

# %%
def reviewCase(company, link):
    ''' Go to the reviews page at link, and collect some simple statistics.
    Add this information into company
    '''
    reviews = {'Star score':'', 'Ceo Approval Rate':'', 'Recommend to Friend Rate':'', 'CEO Name':''}
    browser.get(link)
    try:
        starScore = browser.find_element(By.XPATH, '//*[@id="EmpStats"]/div/div[1]/div/div/div').text

        reviews['Star score'] = starScore
    except Exception as e:
        print(company['name'], ' does not have star score')
    try:
        ceo = browser.find_element(By.XPATH, '//*[@id="EmpStats"]/div/div[2]/div[3]/div/div[2]/div[1]').text
        reviews['CEO Name'] = ceo

        ratings = browser.find_elements(By.CLASS_NAME, 'donut__DonutStyle__donutchart_text_val')

        recommendToFriend = ratings[0].text
        reviews['Recommend to Friend Rate'] = recommendToFriend

        approveOfCeo = ratings[1].text
        reviews['Ceo Approval Rate'] = approveOfCeo
    except Exception as e:
        print(company['name'], ' does not have donut values')
        
    company['Review Section Details'] = reviews

# %% [markdown]
# ### And now we get the seeds!!!!
#
# Some searches seem to tend towards the same result.
#
# For example:
#
# "BANK OF NEW YORK MELLON CORP" on line 76 and
#
# "BNY Mellon Municipal Bond Infrastructure Fund Inc" on line 1258
#
# both go to the same "BNY Mellon" page.In this case these both have the same link.

# %% [markdown]
# Created for Mac OS Chrome Ver. 88.0.4324.96
# chromedriver.exe
#
#
# Downloaded from here:
# https://chromedriver.storage.googleapis.com/index.html?path=88.0.4324.96/
#
# Follow this tutorial to put chromedriver.exe into PATH:
# https://www.edureka.co/community/52315/how-to-setup-chrome-driver-with-selenium-on-macos

# %%
browser = webdriver.Chrome(executable_path="/usr/local/bin/chromedriver")

#enter username and password 
args = {'username':'', 
        'password':'', 
        'url':'https://www.glassdoor.com/member/home/index.htm'}

sign_in(args)
taskOne, taskTwo = gather_seeds(635) #blocked from 635 so start from here
#started at deltic timber after entering captcha info
writeToJson(taskOne, 'taskOne')
writeToJson(taskTwo, 'taskTwo')
browser.quit()
# Out:
# redirected to:  Monster Worldwide  when searching:  Monster Worldwide Inc.
# DPW HOLDINGS INC  does not have donut values
# redirected to:  Quest Diagnostics  when searching:  Quest Diagnostics Inc
# redirected to:  Emclaire Financial  when searching:  Emclaire Financial Corp
# EMCLAIRE FINANCIAL CORP  does not have donut values
# redirected to:  DXP Enterprises  when searching:  DXP Enterprises Inc
# redirected to:  Cal-Maine Foods  when searching:  Cal Maine Foods Inc
# redirected to:  Eltek (Israel)  when searching:  Eltek Ltd
# ELTEK LTD  does not have donut values
# redirected to:  Insperity  when searching:  Insperity Inc.
# redirected to:  Kilroy Realty  when searching:  Kilroy Realty Corp
# redirected to:  8x8  when searching:  8x8 Inc
# redirected to:  Meritor  when searching:  Meritor Inc
# redirected to:  1800PetMeds  when searching:  PetMed Express Inc
# redirected to:  1800PetMeds  when searching:  PetMed Express
# redirected to:  Yum!  when searching:  YUM! Brands Inc.
# redirected to:  FARO Technologies  when searching:  FARO Technologies
# redirected to:  Stewardship Financial  when searching:  Stewardship Financial Corp
# redirected to:  RADCOM  when searching:  Radcom Ltd
# redirected to:  1st Constitution  when searching:  1st Constitution Bancorp
# redirected to:  Pacific Continental  when searching:  Pacific Continental Corp
# redirected to:  Net 1 UEPS  when searching:  Net 1 Ueps Technologies Inc
# redirected to:  Camden National  when searching:  Camden National Corp
# redirected to:  Identiv  when searching:  Identiv Inc
# redirected to:  Annaly Capital Management  when searching:  Annaly Capital Management Inc
# NATIONAL RESEARCH CORP  does not have donut values
# redirected to:  Ritchie Bros.  when searching:  Ritchie Bros Auctioneers Inc
# redirected to:  OSI Systems  when searching:  OSI Systems Inc
# redirected to:  C.H. Robinson  when searching:  C.H. Robinson Worldwide Inc.
# redirected to:  Middleburg Financial  when searching:  Middleburg Financial Corp
# redirected to:  Choice Hotels  when searching:  Choice Hotels International Inc.
# redirected to:  Centerspace  when searching:  Investors Real Estate Trust
# redirected to:  Fairchild Semiconductor  when searching:  Fairchild Semiconductor International Inc.
# redirected to:  China Mobile  when searching:  China Mobile Ltd
# redirected to:  Dril-Quip  when searching:  Dril-Quip Inc.
# redirected to:  CUI Global  when searching:  CUI Global Inc
# redirected to:  Carolina Bank  when searching:  Carolina Bank Holdings Inc
# redirected to:  Ladenburg Thalmann  when searching:  Ladenburg Thalmann Financial Services Inc.
# redirected to:  Group 1 Automotive  when searching:  Group 1 Automotive Inc.
# redirected to:  Capital Senior Living  when searching:  Capital Senior Living Corp
# redirected to:  CTI Industries  when searching:  CTI Industries Corp
# CTI INDUSTRIES CORP  does not have donut values
# redirected to:  Mettler-Toledo  when searching:  Mettler-Toledo International Inc
# redirected to:  MidWestOne Bank  when searching:  MidWestOne Financial Group Inc
# redirected to:  MidWestOne Bank  when searching:  MidWestOne Financial
# redirected to:  Charles & Colvard  when searching:  Charles & Colvard Ltd
# CHARLES & COLVARD LTD  does not have donut values
# redirected to:  Progenics Pharmaceuticals  when searching:  Progenics Pharmaceuticals Inc
# redirected to:  SB One Bank  when searching:  SB One Bancorp
# SB ONE BANCORP  does not have donut values
# redirected to:  GeoSpace Technologies  when searching:  Geospace Technologies Corp
# redirected to:  RealNetworks  when searching:  RealNetworks Inc
# redirected to:  MACOM  when searching:  Applied Micro Circuits Corp
# redirected to:  MACOM  when searching:  Applied Micro Circuits
# redirected to:  BASi  when searching:  Bioanalytical Systems Inc
# redirected to:  Apex Silver Mines  when searching:  Golden Minerals Co
# redirected to:  Apex Silver Mines  when searching:  Golden Minerals
# redirected to:  Assertio  when searching:  Assertio Therapeutics Inc
# ASSERTIO THERAPEUTICS INC  does not have donut values
# redirected to:  C&F Financial  when searching:  C&F Financial Corp
# redirected to:  Envision Healthcare  when searching:  Envision Healthcare Corp
# redirected to:  Ingredion  when searching:  Ingredion Inc
# redirected to:  SAP  when searching:  SAP SE
# redirected to:  Norwegian Cruise Line  when searching:  Norwegian Cruise Line Holdings Ltd
# redirected to:  CEMEX  when searching:  Cemex SAB de CV
# redirected to:  American Tower  when searching:  American Tower Corp
# redirected to:  Paysign  when searching:  Paysign Inc
# PAYSIGN INC  does not have donut values
# SIERRA BANCORP  does not have donut values
# redirected to:  Kirkland Lake Gold  when searching:  Kirkland Lake Gold Ltd
# redirected to:  Brookline Bancorp  when searching:  Brookline Bancorp Inc
# redirected to:  Columbia Sportswear  when searching:  Columbia Sportswear Co
# redirected to:  New Gold  when searching:  New Gold Inc
# redirected to:  Applied DNA Sciences  when searching:  Applied DNA Sciences Inc
# redirected to:  Fauquier Bankshares  when searching:  Fauquier Bankshares Inc
# FAUQUIER BANKSHARES INC  does not have donut values
# redirected to:  PolyMet Mining  when searching:  PolyMet Mining Corp
# POLYMET MINING CORP  does not have donut values
# redirected to:  HopFed Bancorp  when searching:  HopFed Bancorp Inc
# HOPFED BANCORP INC  does not have donut values
# redirected to:  HudBay Minerals  when searching:  Hudbay Minerals Inc
# redirected to:  Peapack-Gladstone Bank  when searching:  Peapack-Gladstone Financial Corp
# redirected to:  Peapack-Gladstone Bank  when searching:  Peapack-Gladstone Financial
# redirected to:  Marker Therapeutics  when searching:  Marker Therapeutics Inc
# MARKER THERAPEUTICS INC  does not have donut values
# redirected to:  Silvercorp Metals  when searching:  Silvercorp Metals Inc
# SILVERCORP METALS INC  does not have donut values
# redirected to:  Pareteum  when searching:  Pareteum Corp
# redirected to:  Ultra Petroleum  when searching:  Ultra Petroleum Corp.
# redirected to:  United Bancshares  when searching:  United Bancshares Inc
# UNITED BANCSHARES INC  does not have donut values
# redirected to:  First Majestic Silver  when searching:  First Majestic Silver Corp
# redirected to:  Westport Fuel Systems  when searching:  Westport Fuel Systems Inc
# WESTPORT FUEL SYSTEMS INC  does not have donut values
# redirected to:  Omega Protein  when searching:  Omega Protein Corp
# redirected to:  Arm  when searching:  Arm Holdings PLC
# redirected to:  Heritage Commerce  when searching:  Heritage Commerce Corp
# HERITAGE COMMERCE CORP  does not have donut values
# redirected to:  First Niagara Financial  when searching:  First Niagara Financial Group Inc
# redirected to:  BNC Bancorp  when searching:  BNC Bancorp
# redirected to:  Manhattan Associates  when searching:  Manhattan Associates Inc
# redirected to:  LaSalle Hotel Properties  when searching:  LaSalle Hotel Properties
# redirected to:  Amkor  when searching:  Amkor Technology Inc
# redirected to:  Infinity Property & Casualty  when searching:  Infinity Property and Casualty Corp
# redirected to:  Southcoast Financial  when searching:  Southcoast Financial Corp
# SOUTHCOAST FINANCIAL CORP  does not have donut values
# redirected to:  Evolving Systems  when searching:  Evolving Systems Inc
# redirected to:  Innospec  when searching:  Innospec Inc
# redirected to:  ICON  when searching:  Icon PLC
# redirected to:  Interpace Dignostics  when searching:  Interpace Diagnostics Group Inc
# redirected to:  Interpace Dignostics  when searching:  Interpace Diagnostics
# redirected to:  Waste Connections  when searching:  Waste Connections Inc.
# redirected to:  AXT  when searching:  AXT Inc
# AXT INC  does not have donut values
# redirected to:  Avalon Holdings  when searching:  Avalon Holdings Corp
# AVALON HOLDINGS CORP  does not have donut values
# NEFF CORP  does not have donut values
# redirected to:  The Hackett Group  when searching:  Hackett Group Inc (The)
# redirected to:  MarineMax  when searching:  MarineMax Inc
# redirected to:  Hawthorn Bancshares  when searching:  Hawthorn Bancshares Inc
# redirected to:  Gildan Activewear  when searching:  Gildan Activewear Inc
# redirected to:  MicroStrategy  when searching:  MicroStrategy Inc
# redirected to:  Union Bank (Vermont)  when searching:  Union Bankshares Inc
# UNION BANKSHARES INC  does not have donut values
# redirected to:  CoBiz Financial  when searching:  CoBiz Financial Inc
# redirected to:  Orrstown Bank  when searching:  Orrstown Financial Services Inc
# redirected to:  Orrstown Bank  when searching:  Orrstown Financial Services
# redirected to:  Cognizant Technology Solutions  when searching:  Cognizant Technology Solutions Corp
# redirected to:  Amdocs  when searching:  Amdocs Ltd
# FIRST BANCORP INC  does not have donut values
# redirected to:  Gerdau  when searching:  Gerdau SA
# redirected to:  GenVec  when searching:  GenVec Inc
# redirected to:  CUMULUS MEDIA  when searching:  Cumulus Media Inc
# redirected to:  LMI Aerospace  when searching:  LMI Aerospace Inc
# redirected to:  CoStar Group  when searching:  CoStar Group Inc
# redirected to:  Bank of Commerce  when searching:  Bank of Commerce Holdings
# redirected to:  Celestica  when searching:  Celestica Inc
# redirected to:  Centrus Energy  when searching:  Centrus Energy Corp
# redirected to:  Sharps Compliance  when searching:  Sharps Compliance Corp
# redirected to:  Mannatech  when searching:  Mannatech Inc
# redirected to:  Salisbury Bancorp  when searching:  Salisbury Bancorp Inc
# redirected to:  Convergys  when searching:  Convergys Corp
# redirected to:  Crown Castle  when searching:  Crown Castle International Corp
# redirected to:  First National Community Bancorp  when searching:  FNCB
# redirected to:  Cemtrex  when searching:  Cemtrex Inc
# redirected to:  IXYS  when searching:  IXYS Corp
# redirected to:  RiceBran Technologies  when searching:  RiceBran Technologies
# RICEBRAN TECHNOLOGIES  does not have donut values
# redirected to:  eBay  when searching:  eBay Inc.
# redirected to:  Goldman Sachs  when searching:  Goldman Sachs Group Inc (The)
# redirected to:  eMagin  when searching:  eMagin Corp
# EMAGIN CORP  does not have donut values
# redirected to:  Mackinac Financial  when searching:  MacKinac Financial Corp
# redirected to:  Xenith Bankshares  when searching:  Xenith Bankshares Inc
# redirected to:  Algonquin Power & Utilities  when searching:  Algonquin Power & Utilities Corp
# redirected to:  WebMD Health  when searching:  Webmd Health Corp
# redirected to:  Eaton Vance  when searching:  Eaton Vance Senior Income
# redirected to:  American Outdoor Brands  when searching:  American Outdoor Brands Corp
# redirected to:  FedNat  when searching:  FedNat Holding Co
# NETWORK-1 TECHNOLOGIES INC  does not have donut values
# redirected to:  NVIDIA  when searching:  NVIDIA Corp
# NVIDIA CORP  does not have donut values
# redirected to:  American Axle & Manufacturing  when searching:  American Axle & Manufacturing Holdings Inc
# CITIZENS FIRST CORP  does not have donut values
# redirected to:  East West Bank  when searching:  East West Bancorp Inc
# redirected to:  AMRI  when searching:  Albany Molecular Research Inc
# redirected to:  1-800-Flowers.com  when searching:  1-800-FLOWERS.COM Inc
# redirected to:  Points International  when searching:  Points International Ltd
# redirected to:  Red Hat  when searching:  Red Hat Inc
# redirected to:  Internet Gold  when searching:  Internet Gold-Golden Lines Ltd
# INTERNET GOLD-GOLDEN LINES  does not have donut values
# redirected to:  NETSCOUT  when searching:  NetScout Systems Inc
# redirected to:  PolarityTE  when searching:  PolarityTE Inc
# redirected to:  Lionbridge  when searching:  Lionbridge Technologies Inc
# redirected to:  Alamos Gold  when searching:  Alamos Gold Inc
# redirected to:  eGain  when searching:  eGain Corp
# redirected to:  Senior Housing Properties  when searching:  Senior Housing Properties Trust
# SENIOR HOUSING PPTYS TRUST  does not have donut values
# redirected to:  United Online  when searching:  United Online Inc
# redirected to:  OMNOVA Solutions  when searching:  OMNOVA Solutions Inc.
# redirected to:  Internap Corporation  when searching:  Internap Corp
# redirected to:  Ultrapar  when searching:  Ultrapar Participacoes SA
# redirected to:  CIRCOR International  when searching:  CIRCOR International Inc
# redirected to:  Vascular Solutions  when searching:  Vascular Solutions Inc
# redirected to:  PCTEL  when searching:  PCTEL Inc
# redirected to:  Radware  when searching:  Radware Ltd
# redirected to:  Citizens Holding  when searching:  Citizens Holding Co
# CITIZENS HOLDING CO  does not have donut values
# redirected to:  WWE  when searching:  World Wrestling Entertainment Inc.
# redirected to:  Bsquare  when searching:  BSQUARE Corp
# redirected to:  Opexa  when searching:  Opexa Therapeutics Inc
# redirected to:  Akamai  when searching:  Akamai Technologies Inc
# redirected to:  Plug Power  when searching:  Plug Power Inc
# redirected to:  NeoGenomics  when searching:  Neogenomics Inc
# redirected to:  Collectors Universe  when searching:  Collectors Universe Inc
# redirected to:  Flexible Solutions  when searching:  Flexible Solutions International
# FLEXIBLE SOLUTIONS INTL INC  does not have donut values
# redirected to:  Intellicheck  when searching:  Intellicheck Inc
# redirected to:  Kratos Defense & Security Solutions  when searching:  Kratos Defense & Security Solutions Inc
# redirected to:  Expedia Group  when searching:  Expedia Group Inc
# redirected to:  Finisar  when searching:  Finisar Corp
# redirected to:  Rudolph Technologies  when searching:  Rudolph Technologies Inc.
# redirected to:  Agilent Technologies  when searching:  Agilent Technologies Inc
# redirected to:  Upside Software  when searching:  SciQuest Inc
# redirected to:  Upside Software  when searching:  SciQuest
# redirected to:  PFSweb  when searching:  PFSweb Inc
# redirected to:  Teledyne Technologies  when searching:  Teledyne Technologies Inc.
# redirected to:  BGC Partners  when searching:  BGC Partners Inc
# redirected to:  WPCS International  when searching:  Wpcs International Inc
# redirected to:  MutualBank  when searching:  MutualFirst Financial Inc
# redirected to:  MutualBank  when searching:  MutualFirst Financial
# redirected to:  PCA  when searching:  Packaging Corp Of America
# redirected to:  PCA  when searching:  Packaging Corp Of America
# redirected to:  Zynex Medical  when searching:  Zynex Inc
# redirected to:  Beasley Broadcast Group  when searching:  Beasley Broadcast Group Inc
# redirected to:  Mattersight  when searching:  Mattersight Corp
# redirected to:  GigaMedia  when searching:  GigaMedia Ltd
# GIGAMEDIA LTD  does not have donut values
# AMERICAS SILVER CORP  does not have donut values
# redirected to:  Shanxi YIDA Special Steel Group  when searching:  China Yida
# redirected to:  Capstone Turbine  when searching:  Capstone Turbine Corp
# redirected to:  EXFO  when searching:  EXFO Inc
# redirected to:  Delta Apparel  when searching:  Delta Apparel Inc
# redirected to:  NetEase.com  when searching:  Netease Inc
# redirected to:  Entegris  when searching:  Entegris Inc
# redirected to:  Maxar Technologies  when searching:  Maxar Technologies Inc
# redirected to:  SMTC  when searching:  SMTC Corp
# redirected to:  Arena Pharmaceuticals  when searching:  Arena Pharmaceuticals Inc
# redirected to:  Keryx Biopharmaceuticals  when searching:  Keryx Biopharmaceuticals Inc
# redirected to:  Illumina  when searching:  Illumina Inc
# ILLUMINA INC  does not have donut values
# redirected to:  Curis  when searching:  Curis Inc
# CURIS INC  does not have donut values
# redirected to:  Lantronix  when searching:  Lantronix Inc
# redirected to:  Bruker  when searching:  Bruker Corp
# redirected to:  Ceragon Networks  when searching:  Ceragon Networks Ltd
# redirected to:  MIND CTI  when searching:  Mind Cti Ltd
# redirected to:  The Medicines Company  when searching:  Medicines Co (The)
# redirected to:  RTI Surgical  when searching:  RTI Surgical Holdings Inc
# redirected to:  Equinix  when searching:  Equinix Inc
# redirected to:  Compugen (isreal)  when searching:  Compugen Ltd
# BELMOND LTD  does not have donut values
# redirected to:  O2Micro  when searching:  O2Micro International Ltd
# redirected to:  Pinnacle Financial Partners  when searching:  Pinnacle Financial Partners Inc
# redirected to:  180 Degree Capital  when searching:  180 Degree Capital Corp
# 180 DEGREE CPTL CORP  does not have donut values
# redirected to:  Middlefield Banc  when searching:  Middlefield Banc Corp
# redirected to:  TTM Technologies  when searching:  TTM Technologies Inc
# redirected to:  DURECT  when searching:  Durect Corp
# redirected to:  Asur  when searching:  Grupo Aeroportuario del Sureste SAB de CV
# redirected to:  Asur  when searching:  Grupo Aeroportuario del Sureste SAB de
# redirected to:  Integer  when searching:  Integer Holdings Corp
# redirected to:  Banro  when searching:  Banro Corp
# redirected to:  Select Bank  when searching:  Select Bancorp Inc
# redirected to:  Sinopec  when searching:  China Petroleum & Chemical Corp Sinopec
# MONSANTO CO  does not have donut values
# redirected to:  Carnival  when searching:  Carnival PLC
# redirected to:  NII Holdings  when searching:  NII Holdings Inc
# redirected to:  Hydrogenics  when searching:  Hydrogenics Corp
# redirected to:  Village Bank & Trust  when searching:  Village Bank and Trust Financial Corp
# redirected to:  Village Bank & Trust  when searching:  Village Bank and Trust Financial
# redirected to:  DZS Inc.  when searching:  Zhone Technologies Inc.
# redirected to:  DZS Inc.  when searching:  Zhone Technologies
# redirected to:  Mutual Bank  when searching:  Bank Mutual Corp
# redirected to:  Mutual Bank  when searching:  Bank Mutual
# redirected to:  TriNet  when searching:  Trinet Group Inc
# redirected to:  IRSA Propiedades Comerciales  when searching:  IRSA Propiedades Comerciales SA
# IRSA PROPIEDADES COMERCIALES  does not have donut values
# redirected to:  Inseego  when searching:  Inseego Corp
# redirected to:  Alliance Fiber Optic Products  when searching:  Alliance Fiber Optic Products Inc
# redirected to:  Exact Sciences  when searching:  EXACT Sciences Corp
# redirected to:  Genco Shipping And Trading  when searching:  Genco Shipping & Trading
# redirected to:  REXAHN Pharmaceuticals  when searching:  Rexahn Pharmaceuticals Inc
# REXAHN PHARMACEUTICALS INC  does not have donut values
# redirected to:  Global Partners  when searching:  Global Partners LP
# redirected to:  Alon USA Energy  when searching:  Alon USA Energy Inc
# redirected to:  CF Industries  when searching:  CF Industries Holdings Inc
# redirected to:  Columbia Property Trust  when searching:  Columbia Property Trust Inc
# redirected to:  CytoSorbents  when searching:  Cytosorbents Corp
# redirected to:  TreeHouse Foods  when searching:  TreeHouse Foods Inc
# redirected to:  Gran Tierra Energy  when searching:  Gran Tierra Energy Inc
# redirected to:  Toyota Motor Corporation  when searching:  CU Bancorp
# redirected to:  Cimpress  when searching:  Cimpress NV
# redirected to:  API Technologies  when searching:  API Technologies Corp
# redirected to:  Omega Flex  when searching:  Omega Flex Inc
# redirected to:  Retail Properties of America  when searching:  Retail Properties of America Inc
# redirected to:  Gladstone Investment  when searching:  Gladstone Investment Corp
# GLADSTONE INVESTMENT CORP  does not have donut values
# redirected to:  Jamba  when searching:  Jamba Inc
# redirected to:  Medivation  when searching:  Medivation Inc
# redirected to:  Chanticleer Holdings  when searching:  Chanticleer Holdings Inc
# CHANTICLEER HOLDINGS INC  does not have donut values
# redirected to:  STRATA Skin Sciences  when searching:  STRATA Skin Sciences Inc
# STRATA SKIN SCIENCES INC  does not have donut values
# redirected to:  Tronox  when searching:  Tronox Ltd
# redirected to:  Investors Bank  when searching:  Investors Bancorp Inc
# redirected to:  Waterstone Financial  when searching:  Waterstone Financial Inc
# WATERSTONE FINANCIAL INC  does not have donut values
# OP BANCORP  does not have donut values
# redirected to:  BioTelemetry  when searching:  VirtualScopics Inc
# redirected to:  BioTelemetry  when searching:  VirtualScopics
# redirected to:  iRobot  when searching:  iRobot Corp
# redirected to:  Spirit AeroSystems  when searching:  Spirit Aerosystems Holdings Inc
# redirected to:  ACCO Brands  when searching:  ACCO Brands Corp
# redirected to:  PharmAthene  when searching:  PharmAthene Inc
# redirected to:  Advaxis  when searching:  Advaxis Inc
# ADVAXIS INC  does not have donut values
# redirected to:  Baidu  when searching:  Baidu Inc
# redirected to:  Seaspan Corporation  when searching:  Seaspan Corp
# redirected to:  RBC Bearings  when searching:  RBC Bearings Inc
# redirected to:  AMERISAFE  when searching:  AMERISAFE Inc
# redirected to:  eFuture (NL)  when searching:  eFuture Holding Inc
# EFUTURE HOLDING INC  does not have donut values
# redirected to:  Town Sports International Holdings  when searching:  Town Sports International Holdings Inc
# redirected to:  Genomic Health  when searching:  Genomic Health Inc
# redirected to:  NxStage  when searching:  NxStage Medical Inc
# redirected to:  Home BancShares  when searching:  Home Bancshares Inc
# redirected to:  Brookdale Senior Living  when searching:  Brookdale Senior Living Inc
# redirected to:  Clear Channel Outdoor  when searching:  Clear Channel Outdoor Holdings Inc
# redirected to:  WestRock  when searching:  KapStone Paper & Packaging Corp
# redirected to:  WestRock  when searching:  KapStone Paper & Packaging
# redirected to:  HollySys Group  when searching:  Hollysys Automation Technologies Ltd
# redirected to:  HollySys Group  when searching:  Hollysys Automation Technologies
# redirected to:  Ameriprise  when searching:  Ameriprise Financial Inc
# MAINSTREET BANCSHARES INC  does not have donut values
# redirected to:  CounterPath Corporation  when searching:  Counterpath Corp
# redirected to:  Crocs  when searching:  Crocs Inc
# redirected to:  Boardwalk Pipelines  when searching:  Boardwalk Pipeline Partners LP
# redirected to:  SunPower  when searching:  SunPower Corp
# redirected to:  Under Armour  when searching:  Under Armour Inc
# redirected to:  StealthGas  when searching:  StealthGas Inc
# STEALTHGAS INC  does not have donut values
# redirected to:  Leidos  when searching:  Leidos Holdings Inc
# redirected to:  Synutra  when searching:  Synutra International Inc
# SYNUTRA INTERNATIONAL INC  does not have donut values
# CORENERGY INFRASTRUCTURE TR  does not have donut values
# redirected to:  ZIOPHARM  when searching:  ZIOPHARM Oncology Inc
# redirected to:  Double Hull Tankers  when searching:  DHT Holdings Inc
# DHT HOLDINGS INC  does not have donut values
# redirected to:  Fidelity National Financial  when searching:  Fidelity National Financial Inc FNF Group
# redirected to:  First Business Bank  when searching:  First Business Financial Services Inc
# redirected to:  First Business Bank  when searching:  First Business Financial Services
# redirected to:  American Railcar Industries  when searching:  American Railcar Industries Inc
# AMERICAN RAILCAR INDS INC  does not have donut values
# redirected to:  Magyar Bancorp  when searching:  Magyar Bancorp Inc
# MAGYAR BANCORP INC  does not have donut values
# redirected to:  DCP Midstream LP  when searching:  DCP Midstream LP
# redirected to:  Origin Agritech  when searching:  Origin Agritech Ltd
# ORIGIN AGRITECH LTD  does not have donut values
# redirected to:  Chaparral Energy  when searching:  Chaparral Energy Inc
# redirected to:  Birks  when searching:  Birks Group Inc
# redirected to:  Summit State  when searching:  Summit State Bank
# redirected to:  Ur-Energy  when searching:  Ur-Energy Inc
# UR ENERGY INC  does not have donut values
# redirected to:  Energy Transfer  when searching:  Energy Transfer LP
# redirected to:  Andeavor  when searching:  Western Refining Inc
# redirected to:  Andeavor  when searching:  Western Refining
# redirected to:  ViacomCBS  when searching:  Viacom Inc
# redirected to:  Copa Airlines  when searching:  Copa Holdings SA
# redirected to:  Castle Brands  when searching:  Castle Brands Inc
# redirected to:  Shanghai Ever Glory  when searching:  Ever-Glory International Group Inc
# redirected to:  Shanghai Ever Glory  when searching:  Ever-Glory International
# redirected to:  Star Bulk  when searching:  Star Bulk Carriers Corp
# redirected to:  Lpath  when searching:  Lpath Inc
# LPATH INC  does not have donut values
# URANIUM ENERGY CORP  does not have donut values
# redirected to:  nTelos  when searching:  NTELOS Holdings Corp
# redirected to:  H&E Equipment Services  when searching:  H&E Equipment Services Inc
# redirected to:  Euroseas  when searching:  Euroseas Ltd
# EUROSEAS LTD  does not have donut values
# redirected to:  Chipotle  when searching:  Chipotle Mexican Grill Inc
# redirected to:  Perion Network  when searching:  Perion Network Ltd
# SUNWORKS INC  does not have donut values
# redirected to:  FIS  when searching:  Fidelity National Information Services Inc
# redirected to:  AmTrust Financial  when searching:  AmTrust Financial Services Inc
# redirected to:  Air Industries Group  when searching:  Air Industries Group Inc
# redirected to:  Lake Shore Bancorp  when searching:  Lake Shore Bancorp Inc
# redirected to:  Liquidity Services  when searching:  Liquidity Services Inc
# redirected to:  Novadaq  when searching:  Novadaq Technologies Inc
# redirected to:  Kraton  when searching:  Kraton Corp
# redirected to:  Alliance Holdings GP  when searching:  Alliance Holdings GP LP
# ALLIANCE HOLDINGS GP LP  does not have donut values
# redirected to:  Compass Diversified Holdings  when searching:  Compass Diversified Holdings
# redirected to:  Pacific Airport Group  when searching:  Grupo Aeroportuario Del Pacifico SA
# redirected to:  Vanda Pharmaceuticals  when searching:  Vanda Pharmaceuticals Inc
# redirected to:  Anavex Life Sciences  when searching:  Anavex Life Sciences Corp
# ANAVEX LIFE SCIENCES CORP  does not have donut values
# redirected to:  Mueller Water Products  when searching:  Mueller Water Products Inc
# redirected to:  Coldwell Banker  when searching:  Regional Health Properties Inc
# redirected to:  India Globalization Capital  when searching:  India Globalization Capital Inc
# INDIA GLOBALIZATION CAPITAL  does not have donut values
# redirected to:  Alphatec Spine  when searching:  Alphatec Holdings Inc

# %% [markdown]
# #### Notes from full drive #1
#
# ###### Main points:
# - may need to compare all companies with same name, and choose whatever company has the most reviews. Ask research ppl
# - If I dont have a sure answer as to what companuy I am looking for and im not sure of my link, should I omit? i.e. how certain do I have to be about the company I select?
# - searching with the ticker is too unreliable so its better to not use
# - Perhaps I could train a model of moving words around in different ways but at this point I feel like I should continue building manually
#
# ### Key Limitation:
# - sometimes the company, job, salary, interview dropdown menu disappears. This means we have to create an entirely new scraper as the results page is completely different. Thus, continually refreshing will probably be the only option, if that doesnt trigger the website to think we are a bot.

# %% [markdown]
# <details>
# <summary>Detailed Points (too many so in drop down mode)</summary>
# <br>
#
# asa - ticker misleading
#
# UHL u-haul?
#
# aep
#
# aflac afl ?
#
# aig - ticker?
#
# ametek - ticker?
#
# amrep - ticker?
#
# trec
#
# adm - archer daniels (ADM)
#
# ash
#
# rex stores redirect bc lower case
#
# automatic data processing
#
# compare lower to lower
#
# avon
#
# azz
#
# british american tobacco
#
# brt aaparetments - brt - ticker cant see images and detect related words... could use ML to choose related words...
#
# Ball corp
#
# popular
#
#
# bank of mellon BK
#
# Bard (C.R) B Barnes
#
# Barnes group
#
# Beckton dickinson and Co
#
# bemis bms
#
# bkh black hills
#
# block H&R reverse order listed
#
# !@ensco rowasn is now ....
#
# robert half international include in in search, not equality.
#
# Bristol Myers Squibb
#
# BP
#
# liveramp - lower all and take away spaces
#
# CDI
#
# cna
#
# csp
#
# csx
#
# cts
#
# campbell sroup - lower strip combine search
#
# Carisle v Carisle IT - CSL
#
# Caterpillar or CAT?
#
# CENTURY LINK ctl TOO DIFFERENT. lowercase and strip would be same
#
# what do we do when there are only iffy otions? better to not select data?
#
# i e multiple similar name but ?
#
# JP Morgan (Chase & is un necessary) also same name company but dif bc logo exists
#
# Coca Cola Consolidated
#
# cohu
#
# use number of views to choose most legit company
#
# commerce bank in in serarch
#
# citi long v name?
#
# Avis in in search - CAR
#
# ca CA ?? CA INC? LOWER AND IN IN SEARCH
#
# COMPUTER TASK CTG TASK?
#
# rave restaurant rave totally wrong ;(
#
# consolidated editonm ed
#
# Biglari steak and shake?
#
# consolodated tomoka
#
# cooper cos inc The cooper company?
#
# TAP
#
# CRANE
#
# ONEMAIN FIN IN IN SEARCH
#
# CROWN HOLDINGS IN IN SEARCH
#
# DST
#
# DATAO DAIO DATA I in in search for data i/o
#
# deere in in search de to get john deere
#
# deluxe in in searchDLX delux corp works best but thuis may not be the case forfr american airlines
#
# Nortech systems
#
# dover v dover crop - user review numbers to compare
#
# Dupont de noumers
#
# </details>
#
# 56 possible errors

# %% [markdown]
# #### Notes from full drive #2
#
# - it seems like no longer using the ticker to search, the use of nltk to normalize text and do a greedy comparison against longname, commonname, and ticker, and having a heuristic to predict which link will be the most legetimate seems to have done well. Testing on rows 11 to 111, we only had 8 sketchy search results.
#
# - I was thinking of using whether a company has an image or not as some sort of bonus point to the heuristic, but this may mess up some of the results. if I want to be safe, I could make the image a requirement. what kind of company would be so lazy to not upload their logo?
#
# - there seems to be a lot of parameters i can adjust to make the search better. Sounds like a machine learning model...
#
# - looks like I need to somehow predict acronyms. But at this point predicting acronyms really depends on the context of the company name. for example, if I search up A V Homes and get Avatar Holdings, I would guess its similar enough. But is it even right? I'm not a professional at determing companies.
#
# - seems like there are some companies that exist and probably have an account on glassdoor but there are exact replicas with sketchy names and dangerous links. It looks like I'm going to have to set a SAFETY FACTOR to cut out some weird redirects.
#
# - looks like long names are usually a better bet than the common name.
#
# - when one of the searches go through, I redirected to a completely unrelated company. How do I prevent this while allowing for acronym changes?
#
# - some names just seem off compared to the ticker. There are [API solutions to this](https://www.marketplace.spglobal.com/en/solutions/api-solutions-(61953ac7-ea64-4fac-926a-feb7f846c2be)) and there seems to have been python wrappers, but they cost money. Another method I could take is [download the capiq SPREAD SHEETS AND CONVERT THE CAPIQ to names there. ](https://nickderobertis.github.io/capiq-excel-downloader-py/) However this would be very memory intensive and would take long. [this seems to be common issue within the last year as well.](https://www.reddit.com/r/investing/comments/bjqlf7/capital_iq_api/) There also seems to be [academic resources](https://www.library.hbs.edu/Find/Databases/Capital-IQ-Identifiers) as well  but this also requires special permission.
#
# <details>
# <summary>Detailed Points</summary>
# <br>
# j ALEXANDER ACTUALLY CORRECT!
#
# american vanguard - legitimate but looks sketchy. Maybe have no safety filter
#
# amrep - longname better
#
# apogee? - longname works better
#
# A V Homes Avatar holdings redirected but too different
#
# Brt Apartments - probably british apartments? - >redirects to apartments.com but different from brtapartments.com. not listed?
#
# Barnes - Barnes and nobles or barns education? - barns group inc exists. longname first is better
#
# </details>
#
# 8/100 errors

# %% [markdown]
# BRITISH AMERICAN TOBACCO - ticker not BAT, is BTE - too risky to allow head concat automatically
#
# BNY Mellon skipped? - could tokenize to match just words, but then becomes sketchy. add more to legal? added Municipal,Bond,Infrastructure,Fund to legal list
#
# AV Homes - AV Holdings add Homes to legal list
#
# Perhaps having a minimal list to compare to might be advantageous, but sometimes misleading
#
# Blocked after DIGITAL TURBINE 615
#
# also much faster when task 2 not needed.
#
# for tomorrow, just make python executable file and turn in

# %% [markdown]
# ### Now we input the URLs into the jsonl file
